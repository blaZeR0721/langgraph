# %%
from langgraph.graph import StateGraph
from typing import TypedDict

# %%
# Define State
class BMIState(TypedDict):
    weight_kg:float
    height_m:float
    bmi:float

# %%
# Define your graph ( Graph Registration )
graph = StateGraph(BMIState)

# add nodes to your graph

# add edges to your graph

# Compile the graph

# Execute the graph
